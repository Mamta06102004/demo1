# %% [markdown]
# <a href="https://colab.research.google.com/github/Mamta06102004/demo1/blob/main/FirstNB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # My First Notebook

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
2+2
# Out:
# 4

# %%
import pandas as pd

titan = pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/refs/heads/main/Titanic.csv')
# pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.csv')

# titan.head()
titan.info()
# titan.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB
